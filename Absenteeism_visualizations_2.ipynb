# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('Absent.csv')

# %%
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %% [markdown]
# Check number of employees with absenteeism hours

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (706, 21)

# %%
plt.style.use('default')
plt.figure(figsize=(10,6))
sns.countplot(x='Absenteeism time in hours',data=df,color='dodgerblue',palette=None)
plt.xlabel('Absenteeism time (in hours)')
plt.ylabel('Number of employees')
plt.title('Count of employees with Absenteeism hours')
plt.savefig('1st.png',dpi=300)

# %%
# plot of ID with absenteesim hoursfig = plt.figure(figsize=(18, 10))
train = pd.read_csv('Absent.csv')
train.at[51, 'ID']=28
train['Reason for absence'].replace({0:20},inplace=True)
train.rename(columns={"Work load Average/day":"work load" },inplace=True)

train.duplicated().sum()
train.drop_duplicates(inplace=True)

train['Reason for absence'].replace({1:'Certain infectious and parasitic diseases',
2:'Neoplasms',
3:'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism',
4:'Endocrine, nutritional and metabolic diseases',
5: 'Mental and behavioral disorders',
6: 'Diseases of the nervous system',
7: 'Diseases of the eye and adnexa',
8:'Diseases of the ear and mastoid process',
9: 'Diseases of the circulatory system',
10: 'Diseases of the respiratory system',
11: 'Diseases of the digestive system',
12: 'Diseases of the skin and subcutaneous tissue',
13: 'Diseases of the musculoskeletal system and connective tissue',
14: 'Diseases of the genitourinary system',
15: 'Pregnancy, childbirth and the puerperium',
16: 'Certain conditions originating in the perinatal period',
17: 'Congenital malformations, deformations and chromosomal abnormalities',
18: 'Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified',
19: 'Injury, poisoning and certain other consequences of external causes',
20: 'External causes of morbidity and mortality',
21:'Factors influencing health status and contact with health services',22:'Patient follow-up' , 23:'Medical consultation', 24:'Blood donation',
25:'Laboratory examination', 26:'Unjustified absence',27:'Physiotherapy', 28:'Dental consultation'},inplace=True)

train['Seasons'].replace({1:'Summer', 2:'Autumn' ,3:'Winter', 4:'Spring'},inplace=True)
train['Day of the week'].replace({2:'Monday', 3:'Tuesday', 4:'Wednesday', 5:'Thursday', 6:'Friday'},inplace=True)

train['Education'].replace({1:'high school', 2:'graduate',3:'postgraduate',4: 'master and doctor'},inplace=True)
data = train.groupby("Seasons")["Absenteeism time in hours"].sum()


fig = plt.figure(figsize=(18, 10))

plt.style.use('default')
yearlySales = train.groupby(['ID', 'Reason for absence'])['Absenteeism time in hours'].sum()
yearlySales.unstack().plot(kind='area',stacked=True, colormap= 'Spectral', figsize=(18, 10) ) ;
# plt.legend(bbox_to_anchor=(1, 0., 0.5, 0.5),loc='best',ncol=1)
plt.xlabel('ID')
plt.ylabel('Total Absenteeism hours')
plt.title('Total absenteeism hours with ID')
# Out:
# Text(0.5, 1.0, 'Total absenteeism hours with ID')

# %%
genre_sales_percentages_by_season = (train.groupby(['ID', 'Reason for absence'])['Absenteeism time in hours'].sum())*(100)/train.groupby(['ID'])['Absenteeism time in hours'].sum()
genre_sales_percentages_by_season.unstack().plot(kind='area',stacked=True, colormap= 'Spectral', grid=False, figsize=(18,10))
# plt.legend(bbox_to_anchor=(1, 0., 0.5, 0.5),loc='best',ncol=2)

# %%
train.shape
train['Reason for absence'].value_counts()
# Out:
# Medical consultation                                                                                   142
# Dental consultation                                                                                    108
# Diseases of the musculoskeletal system and connective tissue                                            55
# Physiotherapy                                                                                           47
# External causes of morbidity and mortality                                                              43
# Injury, poisoning and certain other consequences of external causes                                     40
# Patient follow-up                                                                                       37
# Unjustified absence                                                                                     33
# Laboratory examination                                                                                  31
# ...

# %%
train.ID.value_counts()
# Out:
# 3     97
# 28    75
# 34    50
# 20    42
# 22    41
# 11    40
# 15    36
# 36    34
# 14    29
# 24    28
# 33    24
# 10    23
# 1     23
# 17    20
# 5     18
# 18    16
# 13    15
# 25    10
# 6      8
# 9      8
# 23     8
# 30     7
# 12     7
# 27     6
# 7      6
# 2      6
# 26     5
# 32     5
# 29     4
# 31     3
# 19     3
# 21     3
# 16     2
# 8      2
# 35     1
# 4      1
# Name: ID, dtype: int64

# %%
# df_=pd.read_csv('Absent.csv')
# df_.shape

# import calendar
# df2=df_[df_['Month of absence']>0]
# df2['month_name'] =  df['Month of absence'].apply(lambda x: calendar.month_abbr[x])

# plt.style.use('default')
# month_abs = df2.groupby('month_name')['Absenteeism time in hours'].sum()
# ax = month_abs.plot(kind='bar', figsize=(8,6), legend=False)
# for i, v in enumerate(month_abs.values):
#     ax.text(i-0.2, v + 17, str(np.int(np.round(v))), color='red')
# ax.set_xlabel('Month')
# ax.set_ylabel('Total Absenteeism hours')
# ax.set_title('Total Absenteeism hours by Month')
# plt.show()


plt.style.use('default')
x=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
y=[212,269,755,476,393,411,730,288,291,344,472,402]
plt.figure(figsize=(6,4))
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.bar(x,y,width=0.6)
for i,v in enumerate(y):
    ax.text(i-.26, v + 15,str(v),color='red')
ax.set_xlabel('Month')
ax.set_ylabel('Total Absenteeism hours')
ax.set_title('Total Absenteeism hours by Month')
plt.show()

# %%
season_mapping = {1:'Summer', 2:'Autumn', 3:'Winter', 4:'Spring'}
df['season_name'] = df.Seasons.map(season_mapping)
df['season_name'] = df['season_name'].astype('category')
df.drop_duplicates(['Seasons', 'season_name'])[['Seasons','season_name']]

plt.style.use('default')
season_abs = df.groupby('season_name')['Absenteeism time in hours'].sum()
ax = season_abs.plot(kind='bar', figsize=(6,4), legend=False)
for i, v in enumerate(season_abs.values):
    ax.text(i-.17, v + 15, str(np.int(np.round(v))), color='red')
ax.set_xlabel('Seasons')
ax.set_ylabel('Total Absenteeism hours')
ax.set_title('Total Absenteeism hours by Seasons')
plt.show()

# %%
# day_mapping = {2:'Monday', 3:'Tuesday', 4:'Wednesday', 5:'Thursday', 6:'Friday'}
# df['day_name'] = df['Day of the week'].map(day_mapping)
# df['day_name'] = df['day_name'].astype('category')
# df.drop_duplicates(['Day of the week', 'day_name'])[['Day of the week','day_name']]

# plt.style.use('default')
# season_abs = df.groupby('day_name')['Absenteeism time in hours'].sum()
# order=['Monday','Tuesday','Wednesday','Thursday','Friday']
# ax = season_abs.plot(kind='bar', x=['Monday','Tuesday','Wednesday','Thursday','Friday'], figsize=(6,4), legend=False)
# for i, v in enumerate(season_abs.values):
#     ax.text(i-.17, v + 15, str(np.int(np.round(v))), color='red')
# ax.set_xlabel('Day of the week')
# ax.set_ylabel('Total Absenteeism hours')
# ax.set_title('Total Absenteeism hours by Weekdays')
# plt.show()

plt.style.use('default')
x=['Monday','Tuesday','Wednesday','Thursday','Friday']
y=[1483,1221,1081,539,719]
plt.figure(figsize=(6,4))
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.bar(x,y,width=0.6)
for i,v in enumerate(y):
    ax.text(i-.13, v + 15,str(v),color='red')
ax.set_ylabel('Total Absenteeism hours')
ax.set_xlabel('Day of the week')
ax.set_title('Total Absenteeism hours by Weekdays')
plt.show()

# %%
plt.style.use('default')
sns.FacetGrid(train,hue='Seasons',height=5,aspect=2).map(sns.distplot,"Absenteeism time in hours").add_legend()
plt.xlabel('Absenteeism time (in hours)')
plt.title('Total absenteeism time with season')
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
dist=[]
for distance in list(df['Distance from Residence to Work'].values):
    if distance<=15:
        dist.append('Close')
    elif 15<distance<=35:
        dist.append('Far')
    else:
        dist.append('Very far')
df['Distance_category']=dist
print(df['Distance_category'].value_counts())
# print(df['Distance from Residence to Work'].value_counts())

sum4=df[(df['Distance_category']=='Close')]['Absenteeism time in hours'].sum()
sum5=df[(df['Distance_category']=='Far')]['Absenteeism time in hours'].sum()
sum6=df[(df['Distance_category']=='Very far')]['Absenteeism time in hours'].sum()
print(sum4,sum5,sum6)

sns.set_style('whitegrid')
x=['Close','Far','Very far']
y=[sum4/163,sum5/311,sum6/232]
plt.figure(figsize=(7,5))
sns.barplot(x=x, y=y)
plt.xlabel('Distance from workplace')
plt.ylabel('Average abseentism time (in hours)')
plt.title('Absenteeism time by distance from residence to workplace')
# Out:
# Far         311
# Very far    232
# Close       163
# Name: Distance_category, dtype: int64
# 1602 1942 1499
# Text(0.5, 1.0, 'Absenteeism time by distance from residence to workplace')

# %%
df[(df['Distance_category']=='Close')]['Absenteeism time in hours']
# Out:
# 1        0
# 3        4
# 8       40
# 9        8
# 32       4
#       ...
# 728      4
# 729    120
# 731      2
# 736      4
# 737      0
# Name: Absenteeism time in hours, Length: 163, dtype: int64

# %%
df[(df['Distance_category']=='Far')]['Absenteeism time in hours']
# Out:
# 15      8
# 18      8
# 19      2
# 20      8
# 27      4
#        ..
# 725     4
# 730    16
# 733     8
# 734    80
# 738     0
# Name: Absenteeism time in hours, Length: 311, dtype: int64

# %%
df['Distance_category'].value_counts()
# Out:
# Far         311
# Very far    232
# Close       163
# Name: Distance_category, dtype: int64

# %%
tc=[]
for cost in list(df['Transportation expense'].values):
    if cost<=200:
        tc.append('Cheap')
    elif 200<cost<=300:
        tc.append('Expensive')
    else:
        tc.append('Very expensive')
df['Transportation_cost']=tc
print(df['Transportation_cost'].value_counts())
sum1=df[(df['Transportation_cost']=='Cheap')]['Absenteeism time in hours'].sum()
sum2=df[(df['Transportation_cost']=='Expensive')]['Absenteeism time in hours'].sum()
sum3=df[(df['Transportation_cost']=='Very expensive')]['Absenteeism time in hours'].sum()

print(sum1,sum2,sum3)

sns.set_style('whitegrid')
x=['Cheap','Expensive','Very expensive']
plt.figure(figsize=(7,5))
y=[sum1/296,sum2/345,sum3/65]
plt.xlabel('Transportation expense')
plt.ylabel('Abseentism time (in hours)')
plt.title('Absenteeism time by transportation expense')
sns.barplot(x=x, y=y)
# Out:
# Expensive         345
# Cheap             296
# Very expensive     65
# Name: Transportation_cost, dtype: int64
# 2076 2432 535

# %%
plt.style.use('default')
dis_exp = df.groupby('Distance from Residence to Work')[['Transportation expense']].mean()
ax = dis_exp.plot(kind='bar', figsize=(10,6), legend=False)
for i, v in enumerate(dis_exp.values):
    ax.text(i-.45, v + 3, str(np.int(np.round(v))), color='red')
ax.set_ylabel('Transportation expense')
ax.set_xlabel('Distance from residence to work (in km)')
ax.set_title('Average Transportation expense by distance to work')
plt.show()

# %%
plt.style.use('default')
x=['27','28','29','30','31','32','33','34','36','37','38','39','40','41','43','46','47','48','49','50','53','58']
y=[6,114,7,41,22,13,51,29,50,73,97,8,57,32,23,2,24,6,5,37,1,8]
plt.figure(figsize=(10,8))
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.bar(x,y,width=0.6)
for i,v in enumerate(y):
    ax.text(i-0.25,v+3,str(v),color='red')
ax.set_ylabel('Count of employees')
ax.set_xlabel('Age')
ax.set_title('Age Distribution')
plt.show()
df.Age.value_counts()
# Out:
# 28    114
# 38     97
# 37     73
# 40     57
# 33     51
# 36     50
# 30     41
# 50     37
# 41     32
# 34     29
# 47     24
# 43     23
# 31     22
# 32     13
# 58      8
# 39      8
# 29      7
# 48      6
# 27      6
# 49      5
# 46      2
# 53      1
# Name: Age, dtype: int64

# %%
df['Service time'].value_counts()
# Out:
# 18    131
# 9     119
# 14     85
# 13     72
# 12     60
# 11     50
# 10     50
# 16     36
# 3      23
# 17     20
# 4      16
# 8      13
# 6       7
# 1       7
# 7       6
# 29      5
# 15      4
# 24      2
# Name: Service time, dtype: int64

# %%
plt.style.use('default')
age_abs = df.groupby('Service time')[['Absenteeism time in hours']].mean()
ax = age_abs.plot(kind='bar', figsize=(8,6), legend=False)
for i, v in enumerate(age_abs.values):
    ax.text(i-.25, v + 0.25, str(np.int(np.round(v))), color='red')
ax.set_xlabel('Service time')
ax.set_ylabel('Absenteeism time (in hours)')
ax.set_title('Average Absenteeism time by service time')
plt.show()

# %%
plt.style.use('default')
age_abs = df.groupby('Age')[['Absenteeism time in hours']].mean()
ax = age_abs.plot(kind='bar', figsize=(8,6), legend=False)
for i, v in enumerate(age_abs.values):
    ax.text(i-.25, v + 0.25, str(np.int(np.round(v))), color='red')
ax.set_xlabel('Age')
ax.set_ylabel('Absenteeism time (in hours)')
ax.set_title('Average Absenteeism time by age')
plt.show()

# %%
plt.style.use('default')
age_work_sum = df.groupby('Age')[['Work load Average/day ']].mean()
ax = age_work_sum.plot(kind='bar', figsize=(10,6), legend=False)
for i, v in enumerate(age_work_sum.values):
    ax.text(i-.45, v + 3, str(np.int(np.round(v))), color='red')
ax.set_xlabel('Age')
ax.set_ylabel('Work load average/day')
ax.set_title('Average work load/day by age')
plt.show()

# %%
sum7=df[(df['Disciplinary failure']==0)]['Absenteeism time in hours'].sum()

plt.style.use('default')
sns.set_style('white')
x=['No','Yes']
y=[sum7,0]
sns.barplot(x=x, y=y, palette='husl')
plt.xlabel('Disciplinary failure')
plt.ylabel('Abseentism time (in hours)')
plt.title('Absenteeism time by disciplinary failure')
# Out:
# Text(0.5, 1.0, 'Absenteeism time by disciplinary failure')

# %%
df['Disciplinary failure'].replace({1:'Yes', 0:'No'},inplace=True)
plt.style.use('default')
sns.countplot(x=df['Disciplinary failure'], palette='husl')
plt.xlabel('Disciplinary failure')
plt.title('Count of disciplinary failure')
plt.ylabel('Count')
plt.show()

# %%
plt.style.use('default')
x=['High school','Graduate','Postgraduate','Master & Doctor']
y=[582,46,74,4]
plt.figure(figsize=(6,4))
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.bar(x,y,width=0.6)
for i,v in enumerate(y):
    ax.text(i-0.05,v+5,str(v),color='red')
plt.xlabel('Education')
plt.ylabel('Count of employees')
plt.title('Educationwise count of employees')
print(df.Education.value_counts())
# Out:
# 1    582
# 3     74
# 2     46
# 4      4
# Name: Education, dtype: int64

# %%
edt=[]
for edu in list(df['Education'].values):
    if edu==1:
        edt.append('High school')
    elif edu==2:
        edt.append('Graduate')
    elif edu==3:
        edt.append('Postgraduate')
    else:
        edt.append('Master & Doctor')
df['Edu_category']=edt

sum15=df[(df['Education']==1)]['Absenteeism time in hours'].sum()
sum16=df[(df['Education']==2)]['Absenteeism time in hours'].sum()
sum17=df[(df['Education']==3)]['Absenteeism time in hours'].sum()
sum18=df[(df['Education']==4)]['Absenteeism time in hours'].sum()

plt.style.use('default')
sns.set_style('whitegrid')
x=['High school','Graduate','Postgraduate','Master & Doctor']
y=[sum15/582,sum16/46,sum17/74,sum18/4]
plt.figure(figsize=(7,5))
sns.barplot(x=x, y=y)
plt.xlabel('Education')
plt.ylabel('Absenteeism time (in hours)')
plt.title('Average Abseentism time by education')
# Out:
# Text(0.5, 1.0, 'Average Abseentism time by education')

# %%
plt.style.use('fivethirtyeight')
ax = df.groupby('Age')['Son', 'Pet'].sum().plot(figsize=(8,6))
ax.set_ylabel('Count')
ax.title.set_position([0.5,1.05])
ax.set_title('Count of Pet & Son by Age')
plt.show()
# Out:
# <ipython-input-30-259c7eec941a>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ax = df.groupby('Age')['Son', 'Pet'].sum().plot(figsize=(8,6))

# %%
drink_sum = df[(df['Social drinker'] == True) & (df['Social smoker']==False)]['Absenteeism time in hours'].sum()
smok_sum = df[(df['Social drinker'] == False) & (df['Social smoker']==True)]['Absenteeism time in hours'].sum()
drink_smok_sum = df[(df['Social drinker'] == True) & (df['Social smoker']==True)]['Absenteeism time in hours'].sum()
abs_sum = df[(df['Social drinker'] == False) & (df['Social smoker']==False)]['Absenteeism time in hours'].sum()
absen = [drink_sum, smok_sum, drink_smok_sum, abs_sum]
pie_labels = ['drinker', 'smoker', 'drinker & smoker', 'No drinker/smoker']
fig, ax = plt.subplots(figsize=(8, 6), subplot_kw=dict(aspect="equal"))

def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d})".format(pct, absolute)

plt.style.use('fivethirtyeight')
wedges, texts, autotexts = ax.pie(absen, autopct=lambda pct: func(pct, absen), textprops=dict(color='w'))
ax.legend(wedges, pie_labels, title='Social Drinkers/Smokers', loc='right', bbox_to_anchor=(1, 0, 0.5, 1))
plt.setp(autotexts, size=8, weight="bold")
ax.set_title('Absenteeism by Social Drinkers/Smokers')
plt.show()

# %%
plt.style.use('default')
plt.figure(figsize=(12,6))
ax=sns.barplot(x='Age', y='Absenteeism time in hours',hue='Social drinker', data= df, palette='pastel')
L=plt.legend()
L.get_texts()[0].set_text('Non Drinker')
L.get_texts()[1].set_text('Drinker')
ax.set_ylabel('Absenteeism time (in hours)')
plt.title('Age, Absenteesim time and social drinker')
# Out:
# Text(0.5, 1.0, 'Age, Absenteesim time and social drinker')

# %%
plt.style.use('default')
plt.figure(figsize=(12,6))
ax=sns.barplot(x='Age', y='Absenteeism time in hours',hue='Social smoker', data= df, palette='Set2')
L=plt.legend()
L.get_texts()[0].set_text('Non Smoker')
L.get_texts()[1].set_text('Smoker')
plt.title('Age, Absenteesim time and social smoker')
# Out:
# Text(0.5, 1.0, 'Age, Absenteesim time and social smoker')

# %%
sns.set(rc={'figure.figsize':(8,6)})

plt.style.use('default')
sns.distplot(x=df['Weight'], bins='auto', label='Weight')
plt.xlabel('Weight (in kg)')
plt.ylabel('Distribution')
plt.title("Weight Distribution")
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Weight Distribution')

# %%
sns.set(rc={'figure.figsize':(8,6)})

plt.style.use('default')
sns.distplot(x=df['Height'], bins='auto', label='Height')
plt.xlabel('Height (in cm)')
plt.ylabel('Distribution')
plt.title("Height Distribution")
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Height Distribution')

# %%
df['Reason for absence'].replace({0:20},inplace=True)
df['Reason for absence'].value_counts()
# Out:
# 23    142
# 28    108
# 13     55
# 27     47
# 20     43
# 19     40
# 22     37
# 26     33
# 25     31
# 11     26
# 10     25
# 18     21
# 14     19
# 1      16
# 7      15
# 12      8
# 6       8
# 21      6
# 8       6
# 9       4
# 16      3
# 24      3
# 5       3
# 15      2
# 4       2
# 17      1
# 3       1
# 2       1
# Name: Reason for absence, dtype: int64

# %%
train['Reason for absence'].value_counts()
# Out:
# Medical consultation                                                                                   142
# Dental consultation                                                                                    108
# Diseases of the musculoskeletal system and connective tissue                                            55
# Physiotherapy                                                                                           47
# External causes of morbidity and mortality                                                              43
# Injury, poisoning and certain other consequences of external causes                                     40
# Patient follow-up                                                                                       37
# Unjustified absence                                                                                     33
# Laboratory examination                                                                                  31
# ...

# %%
Id_type=[]
for col in list(df['Reason for absence'].values):
    if col<=21:
        Id_type.append('ICD')
    else:
        Id_type.append('Non ICD')
        
df['ICD category']=Id_type

# %%
df['ICD category'].value_counts()
# Out:
# Non ICD    401
# ICD        305
# Name: ICD category, dtype: int64

# %%
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                  20                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Pet Weight  Height  Body mass index  \
# ...

# %%
sns.set(rc={'figure.figsize':(8,6)})

plt.style.use('seaborn')
sns.distplot(x=df['Absenteeism time in hours'], bins='auto', label='Height')
plt.xlabel('Absenteeism time (in hours)')
plt.title("Distribution of Absenteeism time")
plt.savefig('1st.png',dpi=300)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
